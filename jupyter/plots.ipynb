# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
labels = ["CNN", "LSTM", "CNN+LSTM", "MAC", "HUMAN"]

res = [17.82, 41.07, 46.55, 54.06, 89.3]

plt.title("Accuracy of selected systems on GQA")
plt.xlabel("System Name")
plt.ylabel("Accuracy")
plt.bar(labels, res)
# Out:
# <BarContainer object of 5 artists>
